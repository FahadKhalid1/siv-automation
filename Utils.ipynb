# %%
import os
import shutil

def collect_cg_pdfs(source_root, destination_root):
    """
    Walk through all subfolders of 'source_root' and copy any files that:
    - Start with 'CG. ' (case-sensitive)
    - End with '.pdf' (case-insensitive)
    into the 'destination_root' folder.
    """

    # Ensure destination exists
    os.makedirs(destination_root, exist_ok=True)

    for folder_path, _, files in os.walk(source_root):
        for file_name in files:
            # Match files starting with "CG. " and ending with ".pdf"
            if file_name.startswith("CG. ") and file_name.lower().endswith(".pdf"):
                source_path = os.path.join(folder_path, file_name)
                dest_path = os.path.join(destination_root, file_name)

                # Handle duplicate filenames by appending a counter
                base, ext = os.path.splitext(file_name)
                counter = 1
                while os.path.exists(dest_path):
                    dest_path = os.path.join(destination_root, f"{base}_{counter}{ext}")
                    counter += 1

                try:
                    shutil.copy2(source_path, dest_path)
                    print(f"Copied: {source_path} -> {dest_path}")
                except Exception as e:
                    print(f"Error copying {source_path}: {e}")

if __name__ == "__main__":
    # Example usage:
    source_directory = r"/Users/fahad/Desktop/car_stolen/Cars/"       # 🔹 Change this
    destination_directory = r"/Users/fahad/Desktop/car_stolen/PDFS/"    # 🔹 Change this
    collect_cg_pdfs(source_directory, destination_directory)
# Out:
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/E-CRAFTER/GE/GE-295-TV/CG. GE-295-TV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GE-295-TV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/E-CRAFTER/GE/GE-122-JH/CG. GE-122-JH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GE-122-JH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-592-SH/CG. HB-592-SH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-592-SH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-159-MP/CG. HB-159-MP.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-159-MP.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-880-SW/CG. HB-880-SW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-880-SW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-825-VG/CG. HB-825-VG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-825-VG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-835-SW/CG. HB-835-SW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-835-SW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-800-SW/CG. HB-800-SW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-800-SW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-060-MP/CG. HB-060-MP.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-060-MP.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-143-TW/CG. HB-143-TW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-143-TW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-871-VG/CG. HB-871-VG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-871-VG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HB/HB-207-MP/CG. HB-207-MP.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HB-207-MP.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-971-YC/CG. GZ-971-YC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-971-YC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-898-YC/CG. GZ-898-YC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-898-YC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-960-QR/CG. GZ-960-QR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-960-QR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-232-YD/CG. GZ-232-YD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-232-YD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-283-XB/CG. GZ283XB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ283XB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-283-XB/CG. GZ-283-XB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-283-XB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-327-YD/CG. GZ-327-YD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-327-YD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-144-YD/CG. GZ-144-YD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-144-YD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-579-YC/CG. GZ-579-YC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-579-YC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-894-RZ/CG. GZ-894-RZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-894-RZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-329-ZK/CG. GZ-329-ZK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-329-ZK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-124-RR/CG. GZ-124-RR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-124-RR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-918-QR/CG. GZ-918-QR_compressed.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-918-QR_compressed.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-918-QR/CG. GZ-918-QR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-918-QR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-721-YC/CG. GZ-721-YC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-721-YC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-111-RR/CG. GZ-111-RR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-111-RR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-465-XB/CG. GZ-465-XB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-465-XB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/GZ/GZ-817-YC/CG. GZ-817-YC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-817-YC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HC/HC-439-NJ/CG. HC-439-NJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HC-439-NJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HC/HC-675-GW/CG. HC-675-GW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HC-675-GW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HC/HC-556-NJ/CG. HC-556-NJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HC-556-NJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HC/HC-239-NJ/CG. HC-239-NJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HC-239-NJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HC/HC-687-GW/CG. HC-687-GW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HC-687-GW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HC/HC-690-GW/CG. HC-690-GW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HC-690-GW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HC/HC-695-GW/CG. HC-695-GW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HC-695-GW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HD/HD-962-ZH/CG. HD-962-ZH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HD-962-ZH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HD/HD-117-ZJ/CG. HD-117-ZJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HD-117-ZJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-495-ES/CG. HA-495-ES.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-495-ES.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-807-BN/CG. HA-807-BN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-807-BN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-422-SA/CG. HA-422-SA floutté.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-422-SA floutté.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-422-SA/CG. HA-422-SA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-422-SA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-227-ES/CG. HA-227-ES.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-227-ES.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-301-ES/CG. HA-301-ES.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-301-ES.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-062-RY/CG. HA-062-RY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-062-RY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-062-RY/CG. HA-062-RY floutté.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-062-RY floutté.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-371-TS/CG. HA-371-TS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-371-TS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-436-JA/CG. HA-436-JA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-436-JA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-586-SA/CG. HA-586-SA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-586-SA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-420-ES/CG. HA-420-ES.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-420-ES.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-069-ES/CG. HA-069-ES.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-069-ES.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-340-SA/CG. HA-340-SA floutté.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-340-SA floutté.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-340-SA/CG. HA-340-SA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-340-SA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HA/HA-728-BN/CG. HA-728-BN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-728-BN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HF/HF-536-NH/CG. HF-536-NH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-536-NH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HF/HF-495-NH/CG. HF-495-NH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-495-NH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HF/HF-506-NH/CG. HF-506-NH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-506-NH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HF/HF-574-NH/CG. HF-574-NH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-574-NH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VOLKSWAGEN/ID7/HF/HF-482-NH/CG. HF-482-NH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-482-NH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/IONIQ/FN/FN-652-VH/CG. FN-652-VH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-652-VH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/IONIQ/FN/FN-141-ZN/CG. FN-141-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-141-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/IONIQ/FN/FN-816-ZN/CG. FN-816-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-816-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/IONIQ/FN/FN-692-ZN/CG. FN-692-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-692-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/IONIQ/FN/FN-514-ZN/CG. FN-514-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-514-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/IONIQ/FN/FN-618-ZN/CG. FN-618-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-618-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/IONIQ/FN/FN-826-VS/CG. FN-826-VS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-826-VS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GN/GN-945-LY/CG. GN-945-LY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GN-945-LY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GN/GN-176-LZ/CG. GN-176-LZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GN-176-LZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GN/GN-564-LZ/CG. GN-564-LZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GN-564-LZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GG/GG-059-SZ/CG. GG-059-SZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GG-059-SZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-919-XJ/CG. GR-919-XJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-919-XJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-326-XJ/CG. GR-326-XJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-326-XJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-970-EC/CG. GR-970-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-970-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-644-XJ/CG. GR-644-XJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-644-XJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-468-ED/CG. GR-468-ED.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-468-ED.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-332-ED/CG. GR-332-ED.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-332-ED.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-140-ED/CG. GR-140-ED.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-140-ED.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-296-XK/CG. GR-296-XK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-296-XK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-573-ED/CG. GR-573-ED.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-573-ED.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GR/GR-836-EC/CG. GR-836-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-836-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-081-NA/CG. GP-081-NA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-081-NA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-463-NB/CG. GP-463-NB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-463-NB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-279-DW/CG. GP-279-DW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-279-DW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-400-NA/CG. GP-400-NA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-400-NA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-307-DW/CG. GP-307-DW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-307-DW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-065-NB/CG. GP-065-NB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-065-NB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-355-DW/CG. GP-355-DW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-355-DW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-184-DW/CG. GP-184-DW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-184-DW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-244-NB/CG. GP-244-NB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-244-NB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-907-NA/CG. GP-907-NA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-907-NA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GP/GP-241-DW/CG. GP-241-DW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-241-DW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-458-EM/CG. GK-458-EM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-458-EM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-083-EM/CG. GK-083-EM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-083-EM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-481-EM/CG. GK-481-EM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-481-EM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-651-EL/CG. GK-651-EL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-651-EL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-764-EL/CG. GK-764-EL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-764-EL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-401-EM/CG. GK-401-EM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-401-EM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-921-EL/CG. GK-921-EL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-921-EL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GK/GK-166-EM/CG. GK-166-EM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-166-EM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GL/GL-809-QE/CG. GL-809-QE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-809-QE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GL/GL-719-QE/CG. GL-719-QE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-719-QE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GL/GL-627-QE/CG. GL-627-QE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-627-QE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GQ/GQ-912-PV/CG. GQ-912-PV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-912-PV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GQ/GQ-984-VQ/CG. GQ-984-VQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-984-VQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GQ/GQ-900-PV/CG. GQ-900-PV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-900-PV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GQ/GQ-920-PV/CG. GQ-920-PV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-920-PV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GQ/GQ-893-PV/CG. GQ-893-PV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-893-PV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/CUPRA/GQ/GQ-904-PV/CG. GQ-904-PV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-904-PV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/BUY&DRIVE/CG. W-705-LP.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. W-705-LP.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-141-YE/CG. EE-141-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-141-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-285-YE/CG. EE-285-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-285-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-366-YE/CG. EE-366-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-366-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-207-GH/CG. EE-207-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-207-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-071-YE/CG. EE-071-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-071-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-836-GH/CG. EE-836-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-836-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-516-YE/CG. EE-516-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-516-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-043-YF/CG. EE-043-YF.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-043-YF.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-764-YE/CG. EE-764-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-764-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-156-YF/CG. EE-156-YF.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-156-YF.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-349-GH/CG. EE-349-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-349-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-433-GH/CG. EE-433-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-433-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-650-GH/CG. EE-650-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-650-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-083-YG/CG. EE-083-YG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-083-YG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-501-GH/CG. EE-501-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-501-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-508-YF/CG. EE-508-YF.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-508-YF.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-767-GH/CG. EE-767-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-767-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-424-YE/CG. EE-424-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-424-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-924-GH/CG. EE-924-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-924-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-622-YE/CARTE GRISE/CG. EE-622-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-622-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-965-GG/CG. EE-965-CG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-965-CG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-988-YD/CG. EE-988-YD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-988-YD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-314-YE/CG. EE-314-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-314-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-117-GH/CG. EE-117-GH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-117-GH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-769-YE/CG. EE-769-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-769-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-230-YE/CARTE GRISE/CG. EE-230-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-230-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-383-YE/CG. VERSO EE-383-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. VERSO EE-383-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-383-YE/CG. EE-383-YE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-383-YE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/EE/EE-463-YG/CG. EE-463-YG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EE-463-YG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-066-LQ/CARTE GRISE/CG. ED-066-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-066-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-299-SL/CARTE GRISE/CG. ED-299-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-299-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-268-LR/CARTE GRISE/CG. ED-268-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-268-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-921-SL/CARTE GRISE/CG. ED-921-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-921-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-893-LQ/CARTE GRISE/CG. ED-893-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-893-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-449-LR/CARTE GRISE/CG. ED-449-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-449-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-789-LR/CARTE GRISE/CG. ED-789-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-789-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-389-LQ/CARTE GRISE/CG. ED-389-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-389-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-746-LQ/CARTE GRISE/CG. ED-746-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-746-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-235-LS/CARTE GRISE/CG. ED-235-LS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-235-LS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-601-LQ/CARTE GRISE/CG. ED-601-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-601-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-072-LR/CARTE GRISE/CG. ED-072-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-072-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-750-LP/CARTE GRISE/CG. ED-750-LP.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-750-LP.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-898-LS/CARTE GRISE/CG. ED-898-LS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-898-LS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-783-SL/CARTE GRISE/CG. ED-783-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-783-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-606-LR/CARTE GRISE/CG. ED-606-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-606-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-480-SL/CARTE GRISE/CG. ED-480-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-480-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/INFINITI Q50/ED/ED-634-SL/CARTE GRISE/CG. ED-634-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ED-634-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/JAGUAR XE/EC-019-TF/CG. EC-019-TF.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EC-019-TF.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EJ-173-TB/CG. EJ-173-TB.PDF -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EJ-173-TB.PDF
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-326-LQ/CG. EW-326-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-326-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-788-LQ/CG. EW-788-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-788-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-365-LR/CG. EW-365-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-365-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-847-LQ/CG. EW-847-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-847-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-080-LR/CG. EW-080-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-080-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-261-LR/CG. EW-261-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-261-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-087-LR/CG. EW-087-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-087-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-209-MK/CG. EW-209-MK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-209-MK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-865-LQ/CG. EW-865-LQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-865-LQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EW/EW-402-LR/CG. EW-402-LR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EW-402-LR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-192-SM/CG. EQ-192-SM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-192-SM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-147-LH/CG. EQ-147-LH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-147-LH.pdf
# Error copying /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-931-ZN/CG. EQ-931-ZN.pdf: [Errno 60] Operation timed out: '/Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-931-ZN/CG. EQ-931-ZN.pdf' -> '/Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-931-ZN.pdf'
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-892-ZN/CG. EQ-892-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-892-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-034-SL/CG. EQ-034-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-034-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-940-ZN/CG. EQ-940-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-940-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-922-SK/CG. EQ-922-SK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-922-SK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-996-LG/CG. EQ-996-LG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-996-LG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-745-SM/CG. EQ-745-SM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-745-SM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-889-ZN/CG. EQ-889-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-889-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-942-SL/CG. EQ-942-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-942-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-554-LH/CG. EQ-554-LH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-554-LH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-556-SM/CG. EQ-556-SM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-556-SM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-595-SL/CG. EQ-595-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-595-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-910-SK/CG. EQ-910-SK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-910-SK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-532-LH/CG. EQ-532-LH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-532-LH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-963-LG/CG. EQ-963-LG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-963-LG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-908-ZN/CG. EQ-908-ZN.PDF -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-908-ZN.PDF
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-474-SL/CG. EQ-474-SL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-474-SL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-477-LH/CG. EQ-477-LH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-477-LH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-919-ZN/CG. EQ-919-ZN.PDF -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-919-ZN.PDF
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-939-ZN/CG. EQ-939-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-939-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-326-LH/CG. EQ-326-LH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-326-LH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-932-ZN/CG. EQ-932-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-932-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-891-ZN/CG. EQ-891-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-891-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-926-ZN/CG. EQ-926-ZN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-926-ZN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-488-SM/CG. EQ-488-SM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-488-SM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-337-LH/CG. EQ-337-LH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-337-LH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EQ/EQ-226-LH/CG. EQ-226-LH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EQ-226-LH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-110-QC/CG. EV-110-QC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-110-QC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-874-QN/CG. EV-874-QN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-874-QN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-231-QN/CG. EV-231-QN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-231-QN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-891-QC/CG. EV-891-QC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-891-QC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-606-QB/CG. EV-606-QB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-606-QB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-808-QN/CG. EV-808-QN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-808-QN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-760-QN/CG. EV-760-QN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-760-QN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-679-QB/CG. EV-679-QB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-679-QB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-239-QN/CG. EV-239-QN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-239-QN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EV/EV-023-QD/CG. EV-023-QD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EV-023-QD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EF/EF-882-HB/CG. EF-882-HB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EF-882-HB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EF/EF-302-HW/CG. EF-302-HW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EF-302-HW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EF/EF-615-HB/CG. EF-615-HB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EF-615-HB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/EF/EF-842-HK/CG. EF-842-HK.png.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EF-842-HK.png.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-890-CC/CG. ER-890-CC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-890-CC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-734-CC/CG. ER-734-CC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-734-CC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-313-CC/CG. ER-313-CC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-313-CC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-439-CC/CG. ER-439-CC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-439-CC.pdf
# Error copying /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-203-CC/CG. ER-203-CC.pdf: [Errno 60] Operation timed out: '/Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-203-CC/CG. ER-203-CC.pdf' -> '/Users/fahad/Desktop/car_stolen/PDFS/CG. ER-203-CC.pdf'
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-802-CN/CG. ER-802-CN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-802-CN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-292-CC/CG. ER-292-CC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-292-CC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-153-CC/CG. ER-153-CC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-153-CC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/FORD VIGNALE/ER/ER-617-CC/CG. ER-617-CC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-617-CC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-623-EC/CG. HE-623-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-623-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-623-EC/CG. HE-623-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-623-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-732-EC/CG. HE-732-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-732-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-732-EC/CG. HE-732-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-732-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-194-EC/CG. HE-194-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-194-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-194-EC/CG. HE-194-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-194-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-390-EC/CG. HE-390-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-390-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-390-EC/CG. HE-390-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-390-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-267-EC/CG. HE-267-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-267-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-267-EC/CG. HE-267-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-267-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-337-EC/CG. HE-337-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-337-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-337-EC/CG. HE-337-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-337-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-577-EC/CG. HE-577-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-577-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-577-EC/CG. HE-577-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-577-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-463-EC/CG. HE-463-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-463-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-463-EC/CG. HE-463-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-463-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-517-EC/CG. HE-517-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-517-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-517-EC/CG. HE-517-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-517-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-671-EC/CG. HE-671-EC flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-671-EC flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HE/HE-671-EC/CG. HE-671-EC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HE-671-EC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/CG MODEL Y/CG. GT-654-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-654-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/CG MODEL Y/CG. GT-649-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-649-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/CG MODEL Y/CG. GT-690-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-690-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GZ/GZ-667-EY/CG. GZ-667-EY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-667-EY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GZ/GZ-722-EY/CG. GZ-722-EY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-722-EY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GZ/GZ-763-EY/CG. GZ-763-EY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-763-EY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GZ/GZ-595-EY/CG. GZ-595-EY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-595-EY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GZ/GZ-462-EY/CG. GZ-462-EY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GZ-462-EY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-718-FY/CG. GT-718-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-718-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-629-FY/ASSURANCES ZEGO 2024/CG. GT-629-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-629-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-649-FY/CG. GT-649-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-649-FY_1.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-753-FY/CG. GT-753-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-753-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-643-FY/CG. GT-643-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-643-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-654-FY/CG. GT-654-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-654-FY_1.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-714-FY/CG. GT-714-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-714-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/GT/GT-761-FY/ASSURANCES ZEGO 2024/CG. GT-761-FY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-761-FY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-768-JT/CG. HA-768-JT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-768-JT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-234-FB/CG. HA-234-FB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-234-FB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-988-JT/CG. HA-988-JT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-988-JT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-287-FB/CG. HA-287-FB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-287-FB.pdf
# Error copying /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-158-FB/CG. HA-158-FB.pdf: [Errno 60] Operation timed out: '/Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-158-FB/CG. HA-158-FB.pdf' -> '/Users/fahad/Desktop/car_stolen/PDFS/CG. HA-158-FB.pdf'
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-415-FB/CG. HA-415-FB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-415-FB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-914-JT/CG. HA-914-JT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-914-JT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-368-FB/CG. HA-368-FB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-368-FB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-833-JT/CG. HA-833-JT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-833-JT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-075-FB/CG. HA-075-FB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-075-FB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HA/HA-326-FB/CG. HA-326-FB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-326-FB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-582-AR/CG. HF-582-AR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-582-AR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-582-AR/CG. HF-582-AR flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-582-AR flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-455-AR/CG. HF-455-AR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-455-AR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-455-AR/CG. HF-455-AR flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-455-AR flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-399-AR/CG. HF-399-AR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-399-AR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-399-AR/CG. HF-399-AR flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-399-AR flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-293-JC/CG. HF-293-JC. flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-293-JC. flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-293-JC/CG. HF-293-JC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-293-JC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-509-AR/CG. HF-509-AR flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-509-AR flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-509-AR/CG. HF-509-AR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-509-AR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-548-AR/CG. HF-548-AR flouttée.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-548-AR flouttée.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL Y/HF/HF-548-AR/CG. HF-548-AR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HF-548-AR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GT/GT-992-CN/CG. GT-992-CN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-992-CN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GT/GT-795-CN/CG. GT-795-CN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-795-CN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GT/GT-475-CN/CG. GT-475-CN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-475-CN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GT/GT-174-CP/CG. GT-174-CP.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GT-174-CP.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/DV/DV-592-MS/CG. DV-592-MS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. DV-592-MS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GY/GY-134-VN/CG. GY-134-VN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GY-134-VN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GY/GY-422-VN/CG. GY-422-VN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GY-422-VN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-738-HK/CG. GP-738-HK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-738-HK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-769-HL/CG. GP-769-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-769-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-147-HM/CG. GP-147-HM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-147-HM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-066-HL/CG. GP-066-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-066-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-037-HM/CG. GP-037-HM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-037-HM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-334-HL/CG. GP-334-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-334-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-411-HL/CG. GP-411-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-411-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-583-HL/CG. GP-583-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-583-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-475-HL/CG. GP-475-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-475-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-547-HL/CG. GP-547-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-547-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-670-HK/CG. GP-670-HK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-670-HK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-442-HL/CG. GP-442-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-442-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-513-HL/CG. GP-513-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-513-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-671-HL/CG. GP-671-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-671-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GP/GP-610-HL/CG. GP-610-HL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-610-HL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-522-RJ/CG. HA-522-RJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-522-RJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-522-RJ/CG. HA-522-RJ FLOUTTÉ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-522-RJ FLOUTTÉ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-280-RJ/CG. HA-280-RJ Floutté.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-280-RJ Floutté.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-280-RJ/CG. HA-280-RJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-280-RJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-800-RH/CG. HA-800-RH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-800-RH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-800-RH/CG. HA-800-RH FLOUTTÉ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-800-RH FLOUTTÉ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-037-RJ/CG. HA-037-RJ FLOUTTÉ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-037-RJ FLOUTTÉ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-037-RJ/CG. HA-037-RJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-037-RJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-415-RJ/CG. HA-415-RJ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-415-RJ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/HA/HA-415-RJ/CG. HA-415-RJ FLOUTTÉ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. HA-415-RJ FLOUTTÉ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GL/GL-162-CR/CG. GL-162-CR 2.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-162-CR 2.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GL/GL-162-CR/CG. GL-162-CR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-162-CR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GL/GL-019-CR/CG. GL-019-CR 2.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-019-CR 2.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GL/GL-019-CR/CG. GL-019-CR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-019-CR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GL/GL-816-CR/CG. GL-816-CR 2.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-816-CR 2.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GL/GL-816-CR/CG. GL-816-CR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-816-CR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/TESLA/MODEL 3/GL/GL-894-CR/CG. GL-894-CR 2.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GL-894-CR 2.pdf
# ...
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-936-KZ/CG. ER-936-KZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-936-KZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-456-AT/CG. ER-456-AT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-456-AT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-099-NV/CG. ER-099-NV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-099-NV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-224-VF/CG. ER-224-VF.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-224-VF.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-155-RM/CG. ER-155-RM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-155-RM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-234-BQ/CG. ER-234-BQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-234-BQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-700-VD/CG. ER-700-VD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-700-VD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-218-NV/CG. ER-218-NV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-218-NV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-056-VA/CG. ER-056-VA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-056-VA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-448-JL/CG. ER-448-JL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-448-JL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-088-BT/CG. ER-088-BT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-088-BT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-012-BB/CG. ER-012-BB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-012-BB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-286-BV/CG. ER-286-BV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-286-BV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-835-LB/CG. ER-835-LB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-835-LB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-861-TV/CG. ER-861-TV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-861-TV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-686-AS/CG. ER-686-AS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-686-AS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-017-RM/CG. ER-017-RM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-017-RM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-038-VC/CG. ER-038-VC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-038-VC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-207-AY/CG. ER-207-AY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-207-AY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-900-AZ/CG. ER-900-AZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-900-AZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-766-VE/CG. ER-766-VE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-766-VE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-353-KD/CG. ER-353-KD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-353-KD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-993-NX/CG. ER-993-NX.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-993-NX.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-125-BC/CG. ER-125-BC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-125-BC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-904-VC/CG. ER-904-VC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-904-VC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-540-NX/CG. ER-540-NX.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-540-NX.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-301-RM/CG. ER-301-RM.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-301-RM.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-421-VD/CG. ER-421-VD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-421-VD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-860-RL/CG. ER-860-RL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-860-RL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-148-JL/CG. ER-148-JL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-148-JL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-510-TT/CG. ER-510-TT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-510-TT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-228-VA/CG. ER-228-VA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-228-VA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-631-NT/CG. ER-631-NT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-631-NT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-855-TS/CG. ER-855-TS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-855-TS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-972-NT/CG. ER-972-NT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-972-NT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-679-BT/CG. ER-679-BT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-679-BT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-423-VA/CG. ER-423-VA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-423-VA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-507-BC/CG. ER-507-BC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-507-BC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-692-BP/CG. ER-692-BP.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-692-BP.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-112-VB/CG. ER-112-VB.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-112-VB.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-383-AZ/CG. ER-383-AZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-383-AZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA SUPERB/ER/ER-816-BW/CG. ER-816-BW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ER-816-BW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GS/GS-283-JD/CG. GS-283-JD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GS-283-JD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GS/GS-207-JD/CG. GS-207-JD.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GS-207-JD.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GS/GS-284-JC/CG. GS-284-JC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GS-284-JC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GR/GR-037-XK/CG. GR-037-XK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GR-037-XK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GV/GV-421-VL/CG. GV-421-VL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GV-421-VL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GV/GV-421-VL/CG. GV421VL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GV421VL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GX/GX-006-MT/CG. GX-006-MT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GX-006-MT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/SKODA/SKODA ENYAQ COUPÉ/GX/GX-486-LS/CG. GX-486-LS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GX-486-LS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/PASSAT       EK-868-CY/CG. EK-868-CY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EK-868-CY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GG-424-WN/CG. GG-424-WN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GG-424-WN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GG-441-WN/CG. GG-441-WN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GG-441-WN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GJ-237-AT/CG. GJ-237-AT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GJ-237-AT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GJ-015-NL/CG. GJ-015-NL.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GJ-015-NL.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GH-789-DK/CG. GH-789-DK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GH-789-DK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GK-428-TH/CG. GK-428-TH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-428-TH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GK-921-LV/CG. GK-921-LV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GK-921-LV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GG-443-WN/CG. GG-443-WN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GG-443-WN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GG-447-WN/CG. GG-447-WN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GG-447-WN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/VOLKSWAGEN/X10 ID3/GJ-317-SE/CG. GJ-317-SE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GJ-317-SE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/RENAULT/VDR RESTITUES/ET-682-VE TALISMAN/CG. ET-682-VE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ET-682-VE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/RENAULT/VDR RESTITUES/TALISMAN  FC-485-EV/CG. FC-485-EV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FC-485-EV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/RENAULT/FZ-763-GK SCENIC/CG. FZ-763-GK .pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FZ-763-GK .pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/RENAULT/ET-595-VE TALISMAN/CG. ET-595-VE.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ET-595-VE.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/IONIQ/CG. FN-944-SJ IONIQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FN-944-SJ IONIQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/FORD/EF-710-JN/CG. EF-710-JN.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EF-710-JN.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/FORD/EL-650-XH/CG. EL-650-XH - copie.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EL-650-XH - copie.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/FORD/EL-650-XH/CG. EL-650-XH.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EL-650-XH.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/NISSAN/FG-511-MR  NISSAN LEAF/CG. FG-511-MR.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FG-511-MR.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA FE-879-BW/CG. FE-879-BW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FE-879-BW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA FQ-931-MV/CG. FQ-931-MV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FQ-931-MV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA FF-956-BA/CG. FF-956-BA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FF-956-BA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA SUPERB FF-876-QZ RESTIT 16-06-21/CG. FF-876-QZ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FF-876-QZ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA FR-504-VT RESTIT LE 17-06-21/CG. FR-504-VT.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FR-504-VT.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA SUPERB FF-523-HA/CG. FF-523-HA.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FF-523-HA.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA SUPERB FC-493-AG/CG. FC-493-AG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FC-493-AG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA FG-408-GC/CG. FG-408-GC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FG-408-GC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA SUPERB FC-556-AG/CG. FC-556-AG.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FC-556-AG.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA ES-208-HS/CG. ES-208-HS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ES-208-HS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA ES-108-MS - RESTIT LE 19-12-18/CG. ES-108-MS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ES-108-MS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA FE-540-BW/CG. FE 540 BW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FE 540 BW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/VEHICULES RESTITUES/SKODA OCTAVIA EN-972-KY/CG. EN-972-KY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EN-972-KY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/SKODA ENYAQ GP-803-BV/CG. GP-803-BV.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-803-BV.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/SKODA SUPERB FQ-799-ZC/CG. FQ-799-ZC.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FQ-799-ZC.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/SKODA ENYAQ GQ-435-XW/CG. GQ-435-XW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-435-XW_1.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/SKODA OCTAVIA FL-794-XK/CG. FL-794-XK.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FL-794-XK.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/SKODA ENYAQ GQ-607-XW/CG. GQ-607-XW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GQ-607-XW_1.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/SKODA/SKODA ENYAQ GP-018-BW/CG. GP-018-BW.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. GP-018-BW.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/BMW/restitues/FS-509-FS       BMW SERIE3/CG. FS-509-FS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FS-509-FS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/BMW/restitues/FS-518-FS       BMW SERIE3 RESTIT LE 27-08-21/CG. FS-518-FS.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FS-518-FS.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/BMW/restitues/EH-140-BY      BMW SERIE 3/CG. EH-140-BY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. EH-140-BY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/BMW/restitues/FX-116-RY        BMW SERIE3/CG. FX-116-RY.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. FX-116-RY.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/BMW/restitues/ES-867-HQ       BMW SERIE 2/CG. ES-867-HQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ES-867-HQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/BMW/restitues/ES-764-HQ      BMW SERIE 2/CG. ES-764-HQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ES-764-HQ.pdf
# Copied: /Users/fahad/Desktop/car_stolen/Cars/VEHICULES DE PRÊT/BMW/ET-531-AQ       BMW SERIE 3/CG. ET-531-AQ.pdf -> /Users/fahad/Desktop/car_stolen/PDFS/CG. ET-531-AQ.pdf

# %%
import pandas as pd

def filter_car_models(input_excel, output_excel):
    """
    Reads an Excel sheet, selects rows where 'Modèle' column contains
    specific target car models, and saves them into a new Excel file.
    """

    # ✅ Define target models
    target_models = [
        "MODEL 3",
        "MODEL Y",
        "ENYAQ",
        "C-HR",
        "ID7"
    ]

    # Load the Excel file
    df = pd.read_excel(input_excel)

    # Check if 'Modèle' column exists
    if 'Modèle' not in df.columns:
        raise ValueError("Column 'Modèle' not found in the Excel file.")

    # Convert 'Modèle' to string and uppercase for robust comparison
    df['Modèle'] = df['Modèle'].astype(str).str.upper().str.strip()

    # Filter rows that CONTAIN any of the target model names (partial match)
    mask = df['Modèle'].apply(
        lambda x: any(model in x for model in target_models)
    )
    filtered_df = df[mask]

    # Save the filtered data to a new Excel file
    filtered_df.to_excel(output_excel, index=False)

    print(f"✅ Filtered {len(filtered_df)} rows and saved to: {output_excel}")


if __name__ == "__main__":
    # Example usage:
    input_file = r"/Users/fahad/Desktop/car_stolen/export_vehicle_20251016_1634.xlsx"       # 🔹 Change this
    output_file = r"/Users/fahad/Desktop/car_stolen/filtered_vehicles.xlsx"  # 🔹 Change this
    filter_car_models(input_file, output_file)
# Out:
# ✅ Filtered 850 rows and saved to: /Users/fahad/Desktop/car_stolen/filtered_vehicles.xlsx

# %% [markdown]
# ## Date modified

# %%
import pandas as pd

def format_dates(input_excel, output_excel, date_column):
    """
    Reads an Excel file, reformats dates in a given column to DD/MM/YYYY,
    and removes time information like '00:00:00'.
    """

    # Load the Excel file
    df = pd.read_excel(input_excel)

    # Check if the column exists
    if date_column not in df.columns:
        raise ValueError(f"Column '{date_column}' not found in Excel file.")

    # Convert to datetime (handles text or mixed formats gracefully)
    df[date_column] = pd.to_datetime(df[date_column], errors='coerce')

    # Drop rows with invalid or missing dates (optional)
    # df = df.dropna(subset=[date_column])

    # Reformat date to DD/MM/YYYY (string)
    df[date_column] = df[date_column].dt.strftime('%d/%m/%Y')

    # Save to a new Excel file
    df.to_excel(output_excel, index=False)

    print(f"✅ Dates in '{date_column}' reformatted and saved to: {output_excel}")


if __name__ == "__main__":
    # Example usage:
    input_file = r"/Users/fahad/Desktop/car_stolen/filtered_vehicles.xlsx"       # 🔹 change this
    output_file = r"/Users/fahad/Desktop/car_stolen/filtered_vehicles_date.xlsx"  # 🔹 change this
    column_name = "Date de première immatriculation"      # 🔹 change this

    format_dates(input_file, output_file, column_name)
# Out:
# ✅ Dates in 'Date de première immatriculation' reformatted and saved to: /Users/fahad/Desktop/car_stolen/filtered_vehicles_date.xlsx

# %% [markdown]
# ## Check column Financeur

# %%
import pandas as pd

def remove_missing_financeur(input_excel, output_excel):
    """
    Reads an Excel file, removes rows where the 'Financeur' column
    is missing or empty, and saves the cleaned data to a new Excel file.
    """

    # Load Excel file
    df = pd.read_excel(input_excel)

    # Check if column exists
    if 'Financeur' not in df.columns:
        raise ValueError("Column 'Financeur' not found in the Excel file.")

    # Remove rows where 'Financeur' is missing or empty
    cleaned_df = df[df['Financeur'].notna() & (df['Financeur'].astype(str).str.strip() != '')]

    # Save to a new Excel file
    cleaned_df.to_excel(output_excel, index=False)

    print(f"✅ Removed {len(df) - len(cleaned_df)} rows with missing 'Financeur' values.")
    print(f"💾 Cleaned file saved to: {output_excel}")


if __name__ == "__main__":
    # Example usage
    input_file = r"/Users/fahad/Desktop/car_stolen/filtered_vehicles_date.xlsx"           # 🔹 Change this
    output_file = r"/Users/fahad/Desktop/car_stolen/filtered_vehicles_date_F.xlsx"       # 🔹 Change this

    remove_missing_financeur(input_file, output_file)
# Out:
# ✅ Removed 102 rows with missing 'Financeur' values.
# 💾 Cleaned file saved to: /Users/fahad/Desktop/car_stolen/filtered_vehicles_date_F.xlsx

# %%
import pandas as pd

def map_and_copy_rows(source_excel, destination_excel):
    """
    Reads data from a source Excel file, selects and renames columns
    according to an exact header mapping, and saves to a new Excel file
    with headers preserved exactly as defined.
    """

    # Load source Excel file
    df = pd.read_excel(source_excel)

    # ✅ Define exact mapping from source columns → destination headers
    column_mapping = {
        'Immatriculation': "Numéro d'immatriculation",
        'Constructeur': "Constructeur",
        'Modèle': "Modèle",
        'Date de première immatriculation': [
            "Date de première immatriculation du véhicule",
            "Date du certificat d'immatriculation"
        ],
        'Financeur': "ou (Si personne morale) Raison sociale"
    }

    # ✅ Check all required columns exist in source file
    missing = [col for col in column_mapping if col not in df.columns]
    if missing:
        raise ValueError(f"❌ Missing columns in source file: {missing}")

    # ✅ Create a new DataFrame with exact destination headers
    new_df = pd.DataFrame({
        column_mapping['Immatriculation']: df['Immatriculation'],
        column_mapping['Constructeur']: df['Constructeur'],
        column_mapping['Modèle']: df['Modèle'],
        column_mapping['Date de première immatriculation'][0]: df['Date de première immatriculation'],
        column_mapping['Date de première immatriculation'][1]: df['Date de première immatriculation'],
        column_mapping['Financeur']: df['Financeur']
    })

    # ✅ Save to Excel with headers EXACTLY as defined
    new_df.to_excel(destination_excel, index=False, header=True)

    print(f"✅ Successfully created file: {destination_excel}")
    print(f"📊 Total rows copied: {len(new_df)}")


if __name__ == "__main__":
    # Example usage
    source_file = r"/Users/fahad/Desktop/car_stolen/filtered_vehicles_date_F.xlsx"          # 🔹 Change this
    destination_file = r"/Users/fahad/Desktop/car_stolen/entries.xlsx"   # 🔹 Change this

    map_and_copy_rows(source_file, destination_file)
# Out:
# ✅ Successfully created file: /Users/fahad/Desktop/car_stolen/entries.xlsx
# 📊 Total rows copied: 748

# %%
import os
import pandas as pd

folder_path = "/Users/fahad/Desktop/car_stolen/PDFs"  # change this to your folder path

# Collect all PDF file names
pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith(".pdf")]

# Clean file names: remove "CG. " at start and ".pdf" at end
cleaned_names = []
for f in pdf_files:
    name = f
    if name.lower().endswith(".pdf"):
        name = name[:-4]  # remove .pdf
    if name.startswith("CG. "):
        name = name.replace("CG. ", "", 1)  # remove prefix once
    cleaned_names.append(name.strip())

# Save to Excel
df = pd.DataFrame(cleaned_names, columns=["file_name"])
df.to_excel("all_pdf_files_cleaned.xlsx", index=False)

print(f"✅ Saved {len(cleaned_names)} cleaned file names to all_pdf_files_cleaned.xlsx")
# Out:
# ✅ Saved 1778 cleaned file names to all_pdf_files_cleaned.xlsx

# %%
import os
import pandas as pd

# --- Folder paths ---
pdf_folder = "/Users/fahad/Desktop/car_stolen/PDFs"        # Folder containing PDFs
txt_folder = "/Users/fahad/Desktop/car_stolen/textsVision"     # Folder containing text files

# --- Helper function to clean filenames ---
def clean_name(filename, prefix="CG. ", suffix=".pdf"):
    name = filename
    if name.lower().endswith(suffix):
        name = name[:-len(suffix)]
    if name.startswith(prefix):
        name = name.replace(prefix, "", 1)
    return name.strip()

# --- Collect and clean PDF names ---
pdf_files = [f for f in os.listdir(pdf_folder) if f.lower().endswith(".pdf")]
pdf_names = [clean_name(f, suffix=".pdf") for f in pdf_files]

# --- Collect and clean TXT names ---
txt_files = [f for f in os.listdir(txt_folder) if f.lower().endswith(".txt")]
txt_names = [clean_name(f, suffix=".txt") for f in txt_files]

# --- Merge into DataFrame ---
pdf_df = pd.DataFrame(pdf_names, columns=["pdf_name"])
txt_df = pd.DataFrame(txt_names, columns=["txt_name"])

# Outer join on matching names (to include all)
merged_df = pd.merge(pdf_df, txt_df, how="outer", left_on="pdf_name", right_on="txt_name")

# Save to Excel
merged_df.to_excel("matched_files.xlsx", index=False)

print(f"✅ Saved {len(merged_df)} matched filenames to matched_files.xlsx")
# Out:
# ✅ Saved 1778 matched filenames to matched_files.xlsx

# %%
import os
import re
import pandas as pd

# === CONFIGURATION ===
excel_path    = "filtered_vehicles_date_F.xlsx"      # your Excel (input/output)
text_folder   = "/Users/fahad/Desktop/car_stolen/textsVision"
missing_excel = "missing_excel.xlsx"                 # report for blanks/missing

# Keep EXACT capitalization as canonical labels
KNOWN_FINANCIERS = [
    "VOLKSWAGEN BANK GESELLSCHAFT MIT BESCHRAENKTER HAFTUNG",
    "CREDIT MUTUEL LEASING",
    "TOYOTA FRANCE FINANCEMENT ET TFRF",
    "TOYOTA FRANCE FINANCEMENT ET TERF",
    "VOLKSWAGEN FINANCIAL SERVICES - VOLKSWAGEN BANK",
    "VOLKSWAGEN FINANCIAL SERVICES",
    "VOLKSWAGEN BANK",
    "GCA LEASE",
    "TOYOTA KREDITBANK GMBH",
    "OLINN SERVICES"
]

# === DEFINITE NON-FINANCIER PHRASES (skip if found) ===
BLOCKLIST = [
    "CERTIFICAT D IMMATRICULATION",
    "CERTIFICAT D'IMMATRICULATION",
    "DATE DE 1 RE IMMATRICULATION",
    "DATE DE 1ERE IMMATRICULATION",
    "N° IMMATRICULATION",
    "N IMMAT",
    "IMMAT",
    "A.",
    "B.",
    "EST LE PROPRIETAIRE DU VEHICULE",
    "C.4A",
    "C4A",
    "C.3",
    "C3",
    "C.4.1",
    "C41",
]

# ---------- helpers ----------
def norm_spaces(s: str) -> str:
    return re.sub(r"\s+", " ", s).strip()

def tokenized_whitespace_regex(label: str) -> re.Pattern:
    """Match label ignoring newlines/extra spaces."""
    tokens = [re.escape(t) for t in re.split(r"\s+", label.strip()) if t]
    pattern = r"\b" + r"\s+".join(tokens) + r"\b"
    return re.compile(pattern, flags=re.IGNORECASE)

# Precompile patterns for speed
KNOWN_PATTERNS = [(label, tokenized_whitespace_regex(label)) for label in KNOWN_FINANCIERS]

def get_c1_block(upper_text: str) -> str | None:
    """Extract ~400 characters following C1 / C.1 (usually contains financier)."""
    m = re.search(r"(C\.?\s*1)\s*[:\-]?\s*([\s\S]{0,400})", upper_text)
    if not m:
        return None
    window = m.group(2)

    stop = re.search(r"\n?\s*C\s*[\.\s]?\s*[2345]\b|\n?\s*D\s*[\.\s]?\s*\d\b", window)
    if stop:
        window = window[:stop.start()]

    lines = [norm_spaces(l) for l in window.splitlines() if norm_spaces(l)]
    if not lines:
        return None

    candidate = norm_spaces(" ".join(lines[:2]))
    candidate = re.split(r"\bC\s*[\.\s]?\s*[2345]\b|\bD\s*[\.\s]?\s*\d\b", candidate)[0]
    candidate = re.sub(r"[^A-Z0-9 ,.'&/()\-]", " ", candidate)
    candidate = norm_spaces(candidate)
    return candidate if candidate else None

def pick_financier(upper_text: str) -> str | None:
    """
    1) Return canonical financier name if exact match (ignore surroundings).
    2) Else, return cleaned C1 text (if not in blocklist).
    3) Else, None.
    """
    c1_block = get_c1_block(upper_text)
    if not c1_block:
        return None

    # Step 1: known canonical match
    for canonical, pat in KNOWN_PATTERNS:
        if pat.search(c1_block):
            return canonical  # exact known match only

    # Step 2: fallback to full name, but ignore junk/blocklist
    for bad in BLOCKLIST:
        if bad in c1_block:
            return None

    # must be meaningful (at least 2 alphabetic words)
    if len(re.findall(r"[A-Z]{3,}", c1_block)) < 2:
        return None

    return c1_block


# ---------- main ----------
df = pd.read_excel(excel_path)
financiers = []
missing_rows = []

for _, row in df.iterrows():
    immat = str(row["Immatriculation"]).strip().upper()
    txt_name = f"CG. {immat}.txt"
    txt_path = os.path.join(text_folder, txt_name)

    if not os.path.exists(txt_path):
        financiers.append("")
        missing_rows.append({"Immatriculation": immat, "Reason": "File missing"})
        continue

    with open(txt_path, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    upper_text = raw.upper()
    chosen = pick_financier(upper_text)

    if chosen:
        financiers.append(chosen)
    else:
        financiers.append("")
        missing_rows.append({"Immatriculation": immat, "Reason": "No valid financier found"})

# Write results to same Excel
df["Financier"] = financiers
df.to_excel(excel_path, index=False)
print(f"✅ Updated {excel_path} with 'Financier'.")

# Write missing report
if missing_rows:
    pd.DataFrame(missing_rows).to_excel(missing_excel, index=False)
    print(f"⚠️ {len(missing_rows)} rows saved to {missing_excel}")
else:
    print("🎉 All entries processed successfully.")
# Out:
# ✅ Updated filtered_vehicles_date_F.xlsx with 'Financier'.
# ⚠️ 362 rows saved to missing_excel.xlsx
